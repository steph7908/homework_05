# %% [markdown]
# # Assignment - What's the Weather Like?
#
# ## Background
#
# Whether financial, political, or social -- data's true power lies in its ability to answer questions definitively. So let's take what you've learned about Python requests, APIs, and JSON traversals to answer a fundamental question: "What's the weather like as we approach the equator?"
#
# Now, we know what you may be thinking: _"Duh. It gets hotter..."_
#
# But, if pressed, how would you **provide evidence**?
#
# ## WeatherPy
#
# In this example, you'll be creating a Python script to visualize the weather of 500+ cities across the world of varying distance from the equator. To accomplish this, you'll be utilizing a [simple Python library](https://pypi.python.org/pypi/citipy), the [OpenWeatherMap API](https://openweathermap.org/api), and a little common sense to create a representative model of weather across world cities.
#
# Your objective is to build a series of scatter plots to showcase the following relationships:
#
# * Temperature (F) vs. Latitude
# * Humidity (%) vs. Latitude
# * Cloudiness (%) vs. Latitude
# * Wind Speed (mph) vs. Latitude
#
# Your final notebook must:
#
# * Randomly select **at least** 500 unique (non-repeat) cities based on latitude and longitude.
# * Perform a weather check on each of the cities using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it's being processed with the city number and city name.
# * OPTIONAL: Save both a CSV of all data retrieved and png images for each scatter plot.
#
# As final considerations:
#
# * You must complete your analysis using a Jupyter notebook.
# * You must use the Matplotlib ,Seaborn or Pandas plotting libraries.
# * You must include a written description of three observable trends based on the data.
# * You must use proper labeling of your plots, including aspects like: Plot Titles (with date of analysis) and Axes Labels.
#
# ## Hints and Considerations
#
# * The city data is generated based on random coordinates; as such, your outputs will not be an exact match to the provided starter notebook.
#
# * You may want to start this assignment by refreshing yourself on the [geographic coordinate system](http://desktop.arcgis.com/en/arcmap/10.3/guide-books/map-projections/about-geographic-coordinate-systems.htm).
#
# * Next, spend the requisite time necessary to study the OpenWeatherMap API. Based on your initial study, you should be able to answer  basic questions about the API: Where do you request the API key? Which Weather API in particular will you need? What URL endpoints does it expect? What JSON structure does it respond with? Before you write a line of code, you should be aiming to have a crystal clear understanding of your intended outcome.
#
# * A starter code for Citipy has been provided. However, if you're craving an extra challenge, push yourself to learn how it works: [citipy Python library](https://pypi.python.org/pypi/citipy).
#
# * Lastly, remember -- this is a challenging activity. Push yourself! If you complete this task, then you can safely say that you've gained a strong mastery of the core foundations of data analytics and it will only go better from here. Good luck!
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Don't modify this cell.
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from pprint import pprint

# Import API key
import api_keys

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# Don't modify this cell
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 620

# %% [markdown]
# A lot of starter code has been generated for you. Use the cell below to play with the data to ensure you know what's happening.

# %%
type(cities)
# Out:
# list

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city in `cities` using a series of successive API calls.
# * OPTIONAL: Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# OpenWeatherMap API Key
api_key = api_keys.api_key

# base url for getting api data
base_url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key

# example request
# req = requests.get(base_url + f'&q={cities[0]}').json()

# Your code here. A loop maybe? 
#NOTE: API calls can be slow. They can also be limited. Once you have a list try not to rerun all API calls very often.

# %%
# city_list=['saint louis', 'chicago', 'miami', 'little rock', 'reno', 'los angeles', 'dallas', 'boise', 'tampa', 'davenport']

# %%
city_weather={"City":[],
              "Cloudiness":[],
              "Country":[],
              "Date":[],
              "Humidity":[],
              "Lat":[],
              "Lng":[],
              "Max Temp":[],
              "Wind Speed":[]}
for index, city in enumerate(cities):
# for index, city in enumerate(city_list):
    print(index, city)
#     req=requests.get(base_url + f'&q={city_list[index]}').json()
    req=requests.get(base_url + f'&q={cities[index]}').json()
    time.sleep(1)
    if req['cod']== 200:
        city_weather["City"].append(req['name'])
        city_weather["Cloudiness"].append(req['clouds']['all'])
        city_weather["Country"].append(req['sys']['country'])
        city_weather["Date"].append(req['dt'])
        city_weather["Humidity"].append(req['main']['humidity'])
        city_weather["Lat"].append(req['coord']['lat'])
        city_weather["Lng"].append(req['coord']['lon'])
        city_weather["Max Temp"].append(req['main']['temp_max'])
        city_weather["Wind Speed"].append(req['wind']['speed'])
# Out:
# 0 busselton
# 1 opuwo
# 2 vardo
# 3 shelabolikha
# 4 mar del plata
# 5 touros
# 6 tres arroyos
# 7 hobart
# 8 skibotn
# 9 punta arenas
# 10 aksarka
# 11 hermanus
# 12 sao luiz gonzaga
# 13 san cristobal
# 14 vienne
# 15 ushuaia
# 16 yellowknife
# 17 natal
# 18 sentyabrskiy
# 19 fort nelson
# 20 luderitz
# 21 boguchany
# 22 hithadhoo
# 23 rikitea
# 24 along
# 25 chuy
# 26 tsihombe
# 27 coahuayana
# 28 qui nhon
# 29 severodvinsk
# 30 port elizabeth
# 31 airai
# 32 belushya guba
# 33 warqla
# 34 qaanaaq
# 35 taltal
# 36 nanortalik
# 37 uzumlu
# 38 kapaa
# 39 mayumba
# 40 new norfolk
# 41 presidencia roque saenz pena
# 42 albany
# 43 butaritari
# 44 kamenskoye
# 45 puerto ayora
# 46 narsaq
# 47 attawapiskat
# 48 aklavik
# 49 byron bay
# 50 bluff
# 51 fevralsk
# 52 gao
# 53 pucallpa
# 54 saint george
# 55 marsh harbour
# 56 eydhafushi
# 57 watertown
# 58 hornepayne
# 59 kuche
# 60 kinanah
# 61 jamestown
# 62 arraial do cabo
# 63 georgetown
# 64 mataura
# 65 kodiak
# 66 bengkulu
# 67 illoqqortoormiut
# 68 taolanaro
# 69 beringovskiy
# 70 barentsburg
# 71 sao filipe
# 72 saldanha
# 73 filotion
# 74 marawi
# 75 atar
# 76 buchanan
# 77 shalazhi
# 78 auki
# 79 port hawkesbury
# 80 faanui
# 81 amderma
# 82 stromness
# 83 teknaf
# 84 mahebourg
# 85 gunjur
# 86 avarua
# 87 sibolga
# 88 ozgon
# 89 fortuna
# 90 ribeira grande
# 91 norman wells
# 92 castro
# 93 thompson
# 94 minden
# 95 polunochnoye
# 96 homer
# 97 klaksvik
# 98 dabat
# 99 tasiilaq
# 100 lorengau
# 101 broken hill
# 102 sulurpeta
# 103 longyearbyen
# 104 aras
# 105 pevek
# 106 paka
# 107 spirit river
# 108 ponta do sol
# 109 leogane
# 110 blackpool
# 111 paamiut
# 112 dakar
# 113 aksu
# 114 coquimbo
# 115 hilo
# 116 tuktoyaktuk
# 117 cabo san lucas
# 118 bredasdorp
# 119 zemio
# 120 kloulklubed
# 121 yershov
# 122 ghugus
# 123 chumikan
# 124 mattru
# 125 barletta
# 126 panama city
# 127 mwene-ditu
# 128 kaohsiung
# 129 port alfred
# 130 picota
# 131 devarkonda
# 132 arnoldstein
# 133 labutta
# 134 tilichiki
# 135 kudahuvadhoo
# 136 saint-augustin
# 137 asau
# 138 bedesa
# 139 torbay
# 140 salym
# 141 quatre cocos
# 142 barrow
# 143 izumo
# 144 jinxiang
# 145 marystown
# 146 sharan
# 147 royan
# 148 monroe
# 149 la ronge
# 150 cap malheureux
# 151 bosaso
# 152 cidreira
# 153 nakambala
# 154 grand gaube
# 155 vao
# 156 lusambo
# 157 kolobovo
# 158 kaniama
# 159 bethel
# 160 roald
# 161 deputatskiy
# 162 nikolskoye
# 163 yerbogachen
# 164 caruray
# 165 ahipara
# 166 mehamn
# 167 muros
# 168 vaini
# 169 amapa
# 170 bilibino
# 171 provideniya
# 172 leningradskiy
# 173 fairbanks
# 174 port macquarie
# 175 porto novo
# 176 constitucion
# 177 meulaboh
# 178 half moon bay
# 179 orgun
# 180 snasa
# 181 khatanga
# 182 safaga
# 183 pangnirtung
# 184 karratha
# 185 gravdal
# 186 san patricio
# 187 kamaishi
# 188 machali
# 189 upernavik
# 190 mackay
# 191 sitka
# 192 cherskiy
# 193 tidore
# 194 san juan
# 195 svetlogorsk
# 196 saint-pierre
# 197 bud
# 198 atuona
# 199 xichang
# 200 east london
# 201 vostok
# 202 hoquiam
# 203 robertsport
# 204 anadyr
# 205 itupiranga
# 206 esmeralda
# 207 pisco
# 208 ancud
# 209 nguiu
# 210 russell
# 211 maldonado
# 212 tairua
# 213 mys shmidta
# 214 kruisfontein
# 215 allada
# 216 aripuana
# 217 manono
# 218 diebougou
# 219 katsuura
# 220 ilulissat
# 221 cape town
# 222 perth
# 223 bandarbeyla
# 224 khani
# 225 trinidad
# 226 grand river south east
# 227 chokurdakh
# 228 varzea grande
# 229 beroroha
# 230 kalmunai
# 231 shubarshi
# 232 methoni
# 233 ostrovnoy
# 234 lompoc
# 235 dikson
# 236 lae
# 237 samalaeulu
# 238 lata
# 239 thunder bay
# 240 yar-sale
# 241 dickinson
# 242 tokur
# 243 mehriz
# 244 avera
# 245 yulara
# 246 panzhihua
# 247 keffi
# 248 port arthur
# 249 saint-philippe
# 250 hirara
# 251 rafsanjan
# 252 kaoma
# 253 meyungs
# 254 kharan
# 255 ornskoldsvik
# 256 tabukiniberu
# 257 otorohanga
# 258 bambous virieux
# 259 tual
# 260 viedma
# 261 bonthe
# 262 tortoli
# 263 zyryanka
# 264 plettenberg bay
# 265 altay
# 266 lyubytino
# 267 kayerkan
# 268 kavaratti
# 269 aurillac
# 270 azimur
# 271 samusu
# 272 kindu
# 273 san rafael
# 274 dunedin
# 275 salalah
# 276 pincher creek
# 277 hvide sande
# 278 zhigansk
# 279 lebu
# 280 oktyabrskoye
# 281 mandalgovi
# 282 saquarema
# 283 primorsko-akhtarsk
# 284 kanye
# 285 ngunguru
# 286 hasaki
# 287 azul
# 288 longlac
# 289 saskylakh
# 290 carnarvon
# 291 orlik
# 292 devils lake
# 293 san juan evangelista
# 294 surt
# 295 lasa
# 296 ust-nera
# 297 sao joao da barra
# 298 isangel
# 299 moindou
# 300 lavrentiya
# 301 lampa
# 302 esperance
# 303 nome
# 304 harper
# 305 whitehorse
# 306 mount isa
# 307 leshukonskoye
# 308 reconquista
# 309 matamoros
# 310 kirakira
# 311 nantucket
# 312 moose factory
# 313 aporawan
# 314 jardim
# 315 yefremov
# 316 paso de patria
# 317 kaitangata
# 318 kaiyuan
# 319 namibe
# 320 romny
# 321 davila
# 322 mount gambier
# 323 hofn
# 324 dingle
# 325 escarcega
# 326 caravelas
# 327 palu
# 328 barra
# 329 palmer
# 330 praia
# 331 te anau
# 332 grao mogol
# 333 lagoa
# 334 dawei
# 335 kroya
# 336 kidal
# 337 dudinka
# 338 rio gallegos
# 339 bathsheba
# 340 mareeba
# 341 margate
# 342 iqaluit
# 343 coracora
# 344 dwarka
# 345 calabozo
# 346 coihaique
# 347 ulladulla
# 348 tabiauea
# 349 port augusta
# 350 komsomolskiy
# 351 jizan
# 352 sinop
# 353 wampusirpi
# 354 kyzyl-suu
# 355 ossora
# 356 horta
# 357 xinyang
# 358 norrkoping
# 359 tiarei
# 360 sept-iles
# 361 doka
# 362 fare
# 363 novoselytsya
# 364 dolores
# 365 nishihara
# 366 taksimo
# 367 boli
# 368 boke
# 369 pierre
# 370 mangai
# 371 hilton head island
# 372 vidim
# 373 tautira
# 374 faya
# 375 manokwari
# 376 pastavy
# 377 puerto cabezas
# 378 lolua
# 379 barra do corda
# 380 makakilo city
# 381 wairoa
# 382 povenets
# 383 morehead
# 384 mazagao
# 385 bairiki
# 386 port hardy
# 387 moen
# 388 onega
# 389 zeya
# 390 clyde river
# 391 zachagansk
# 392 kontagora
# 393 arona
# 394 mergui
# 395 pennagaram
# 396 balabac
# 397 talara
# 398 viligili
# 399 araouane
# 400 razdolnoye
# 401 hit
# 402 umzimvubu
# 403 camana
# 404 victoria
# 405 suntar
# 406 bastia
# 407 tabulbah
# 408 aldergrove
# 409 palabuhanratu
# 410 yeletskiy
# 411 tsiroanomandidy
# 412 kangra
# 413 kavieng
# 414 portland
# 415 puerto escondido
# 416 zverinogolovskoye
# 417 san quintin
# 418 el wasta
# 419 turtas
# 420 abnub
# 421 hobyo
# 422 digby
# 423 bontang
# 424 kaeo
# 425 diapaga
# 426 kenai
# 427 tigil
# 428 bur gabo
# 429 fomboni
# 430 okhotsk
# 431 tiksi
# 432 lyubeshiv
# 433 nandu
# 434 leh
# 435 carupano
# 436 goteborg
# 437 pakwach
# 438 abha
# 439 kawayan
# 440 mayo
# 441 pangoa
# 442 guerrero negro
# 443 vila velha
# 444 anyang
# 445 conceicao do araguaia
# 446 fort saint james
# 447 rocha
# 448 gopalganj
# 449 vydrino
# 450 konevo
# 451 codrington
# 452 armacao dos buzios
# 453 manbij
# 454 awjilah
# 455 talnakh
# 456 turukhansk
# 457 loa janan
# 458 kattivakkam
# 459 namatanai
# 460 kaya
# 461 maloarkhangelsk
# 462 deli tua
# 463 sinnamary
# 464 puerto lempira
# 465 la cruz
# 466 sidi bu zayd
# 467 gobabis
# 468 vanimo
# 469 sorland
# 470 santa isabel do rio negro
# 471 westpunt
# 472 acarau
# 473 medina del campo
# 474 chenzhou
# 475 cayenne
# 476 imbituba
# 477 tubruq
# 478 sturgeon falls
# 479 pimentel
# 480 naze
# 481 kilindoni
# 482 goure
# 483 orodara
# 484 tuatapere
# 485 wilmington
# 486 alta floresta
# 487 bakhchysaray
# 488 hot springs
# 489 hokitika
# 490 rawson
# 491 payo
# 492 san vicente
# 493 noumea
# 494 srednekolymsk
# 495 barentu
# 496 vilhena
# 497 hohhot
# 498 carutapera
# 499 marathon
# 500 caucaia
# 501 mikhaylovka
# 502 santa maria da boa vista
# 503 egvekinot
# 504 berekum
# 505 diego de almagro
# 506 labuhan
# 507 maunabo
# 508 dunmore town
# 509 whitefish
# 510 vrangel
# 511 nemuro
# 512 kununurra
# 513 huilong
# 514 richards bay
# 515 grindavik
# 516 coffs harbour
# 517 staraya poltavka
# 518 skalistyy
# 519 harer
# 520 saquena
# 521 inderborskiy
# 522 porto santo
# 523 camacha
# 524 vaitupu
# 525 anloga
# 526 ye
# 527 tucuman
# 528 batagay-alyta
# 529 kahului
# 530 waddan
# 531 mairi
# 532 husavik
# 533 waipawa
# 534 saint-francois
# 535 muroto
# 536 qaqortoq
# 537 manta
# 538 kapoeta
# 539 sri aman
# 540 pitimbu
# 541 oranjemund
# 542 dzhusaly
# 543 ekhabi
# 544 broome
# 545 fairfield
# 546 valparaiso
# 547 basco
# 548 sao miguel do araguaia
# 549 hamilton
# 550 ilhabela
# 551 worthington
# 552 kabanjahe
# 553 nelson bay
# 554 senneterre
# 555 estelle
# 556 luanda
# 557 agva
# 558 saint-denis
# 559 puerto del rosario
# 560 hambantota
# 561 inirida
# 562 lazaro cardenas
# 563 koslan
# 564 contamana
# 565 austintown
# 566 tabuk
# 567 west bay
# 568 la orilla
# 569 flinders
# 570 mandan
# 571 daxian
# 572 dubbo
# 573 alofi
# 574 pskov
# 575 kokomo
# 576 marcona
# 577 najran
# 578 flin flon
# 579 poum
# 580 nkhata bay
# 581 sovetskiy
# 582 chapais
# 583 paraiso
# 584 acapulco
# 585 roma
# 586 knysna
# 587 ferrol
# 588 alto paraguai
# 589 malakal
# 590 visby
# 591 demidov
# 592 trairi
# 593 diu
# 594 panaba
# 595 rabaul
# 596 victoria point
# 597 bargal
# 598 arlit
# 599 soure
# 600 banda aceh
# 601 praia da vitoria
# 602 karatsu
# 603 puerto madryn
# 604 itapecerica
# 605 cocorit
# 606 severo-kurilsk
# 607 north bend
# 608 sambava
# 609 wanning
# 610 yinchuan
# 611 vikhorevka
# 612 dickson
# 613 gilazi
# 614 basoko
# 615 rio brilhante
# 616 tura
# 617 singkang
# 618 hvammstangi
# 619 san jose

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * OPTIONAL: Export the city data into a .csv.
# * Display the DataFrame

# %%
# Out:
# City          547
# Cloudiness    547
# Country       547
# Date          547
# Humidity      547
# Lat           547
# Lng           547
# Max Temp      547
# Wind Speed    547
# dtype: int64

# %%
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0     lompoc           1      US  1534984500        44  34.64 -120.46
# 1   klaksvik          92      FO  1534983600       100  62.23   -6.59
# 2  bisignano           0      IT  1534981800        88  39.50   16.27
# 3       hilo          90      US  1534984860        90  19.71 -155.08
# 4    rikitea           8      PF  1534986579       100 -23.12 -134.97
#
#    Max Temp  Wind Speed
# 0     77.00       11.41
# 1     50.00       13.87
# 2     66.20        5.82
# 3     77.00        8.05
# 4     69.58       19.71

# %%
city_weather_df = pd.DataFrame(city_weather)
city_weather_df
# Out:
#               City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Busselton          10      AU  1600832581        44 -33.65  115.33
# 1            Opuwo           3      NA  1600832583        38 -18.06   13.84
# 2            Vardø          20      NO  1600832584        76  70.37   31.11
# 3     Shelabolikha         100      RU  1600832585        70  53.41   82.62
# 4    Mar del Plata         100      AR  1600832586        76 -38.00  -57.56
# ..             ...         ...     ...         ...       ...    ...     ...
# 556         Basoko           4      CD  1600833531        83   1.24   23.62
# 557  Rio Brilhante           0      BR  1600833534        84 -21.80  -54.55
# 558           Tura          97      IN  1600833536        96  25.52   90.22
# 559       Singkang          20      MY  1600833537        74   2.10  102.80
# 560       San Jose          20      US  1600833305        63  37.34 -121.89
#
#      Max Temp  Wind Speed
# 0       71.01        3.58
# 1       59.70        1.03
# 2       37.40        8.05
# 3       46.40       13.42
# 4       54.00        9.17
# ..        ...         ...
# 556     70.86        1.21
# 557     65.80        6.58
# 558     75.58        5.12
# 559     86.00        5.82
# 560     66.99        8.05
#
# [561 rows x 9 columns]

# %%
city_weather_df.to_csv("City_Weather.csv", index=True, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Use matplotlib
# * OPTIONAL: Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
fig, ax = plt.subplots()
ax.scatter(city_weather["Lat"], city_weather["Max Temp"], marker = '.', linestyle="None", color='g')
ax.set_xlabel("Latitude")
ax.set_ylabel("Max Temperature (F)")
ax.set_title("City Latitude vs. Max Temperature (09/22/20)")
ax.grid(True)
plt.savefig('CityLat_v_MaxTemp.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig, ax = plt.subplots()
ax.scatter(city_weather["Lat"], city_weather["Humidity"], marker = '.', linestyle="None", color="b")
ax.set_xlabel("Latitude")
ax.set_ylabel("Humidity (%)")
ax.set_title("City Latitude vs. Humidity (09/22/20)")
ax.grid(True)
plt.savefig('CityLat_v_Humidity.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig, ax = plt.subplots()
ax.scatter(city_weather["Lat"], city_weather["Cloudiness"], marker = '.', linestyle="None", color="y")
ax.set_xlabel("Latitude")
ax.set_ylabel("Cloudiness (%)")
ax.set_title("City Latitude vs. Cloudiness (09/22/20)")
ax.grid(True)
plt.savefig('CityLat_v_Cloudiness.png')
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig, ax = plt.subplots()
ax.scatter(city_weather["Lat"], city_weather["Wind Speed"], marker = '.', linestyle="None")
ax.set_xlabel("Latitude")
ax.set_ylabel("Wind Speed (mph)")
ax.set_title("City Latitude vs. Wind Speed (09/22/20)")
ax.grid(True)
plt.savefig('CityLat_v_WindSpeed.png')
plt.show()

# %% [markdown]
# ### Use the Seaborn library to re-create 2-4 of the above plots.
# * Use the same data just make a different plot.
# * Note the differences in amount of code required to generate a similar plot.

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.set_palette("Greens_r")
g=sns.scatterplot(x="Lat", y="Max Temp", data=city_weather)
g.set(xlabel="Latitude", ylabel="Max Temperature (F)")
g.set_title("City Latitude vs. Max Temperature (09/22/20)")
plt.show()

# %%
sns.set_style("whitegrid")
sns.set_palette("Blues_r")
g=sns.scatterplot(x="Lat", y="Humidity", data=city_weather)
g.set(xlabel="Latitude", ylabel="Humidity (%)")
g.set_title("City Latitude vs. Humidity (09/22/20)")
plt.show()

# %%
sns.set_style("whitegrid")
sns.set_palette("YlOrBr_r")
g=sns.scatterplot(x="Lat", y="Cloudiness", data=city_weather)
g.set(xlabel="Latitude", ylabel="Cloudiness (%)")
g.set_title("City Latitude vs. Cloudiness (09/22/20)")
plt.show()

# %%
sns.set_style("whitegrid")
sns.set_palette("RdBu")
g=sns.scatterplot(x="Lat", y="Wind Speed", data=city_weather)
g.set(xlabel="Latitude", ylabel="Wind Speed (mph)")
g.set_title("City Latitude vs. Wind Speed (09/22/20)")
plt.show()

# %% [markdown]
# ### As a Data-Scientist:
# In addition to generating data, munging data and plotting data you will also be responsible for *interpreting* data.
# * Provide a written description of three observable trends based on the data.

# %%
# The closer you are to 0 Latitude, the warmer the max temperature.
# Humidity % is high no matter how close you are to 0 Latitude.
# Cloudiness and wind speed don't seem to be dependent on a City's Latitude

# %% [markdown]
# ### OPTIONAL Homework Problem:
# * Use a **different** api endpoint such as `Hourly Forecast 4 days` to get data.
# * Other weather api endpoints are documented [here](https://openweathermap.org/api).
# * You will have to change the URL parameters to get the data you want.
# * Get the data into a data structure of your choice. (Pandas, dicts, lists etc...)
# * Use the plotting library of your choice to make 1-4 plots of your choice.
